# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline

#plt.style.use('default')
pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)
plt.rcParams['font.family'] = 'sans-serif'

plt.style.use('seaborn-whitegrid')
# Out:
# /home/koen/anaconda3/envs/bunnies/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Create function to group the same species together
def filterSpecies(inputString,test=False):
    
    # make input lower case
    checkString = inputString.lower()
    
    # list of most likely shark species
    sharklist = ['white shark','bull shark','hammerhead shark','tiger shark',\
                 'wobbegong shark','sevengill shark','nurse shark','mako shark',\
                 'blue shark','zambezi shark','whaler shark','blacktip shark',\
                 'bonita shark','reef shark', 'lemon shark', 'angel shark',\
                 'dogfish shark','spinner shark','goblin shark','whale shark',\
                 'silky shark','zambesi shark','raggedtooth shark']
    
    species = ''
    for shark in sharklist:
        if shark in checkString:
            species = shark
            break
            
    if(species == ''):
        species = 'Unspecified'
            
    if(test):
        print species
        
    return species

# Create function to group the same activities together
def groupActivity(inputString,test=False):
    
    # make input lower case
    checkString = inputString.lower()
    
    # list of most likely shark species
    activityList = ['surfing','swimming','diving','fishing','boarding','wading','standing','snorkeling',\
                    'skiing','canoeing','kayaking','floating','walking','bathing','sitting','rowing',\
                    'watching','paddling','playing','treading','dangling']
    
    activity = ''
    for act in activityList:
        if act in checkString:
            activity = act
            break
            
    if(activity == ''):
        #print "'"+checkString+"'"
        activity = 'other'
            
    #if(test):
    #    print activity
        
    return activity

# %%
# Create a pandas Series for the yearly overview of a particular item in the column
def createYearOverviewItem(df,columnName,item):
    
    item_record = df.groupby([columnName]).get_group(item)
    year_groupby = item_record.groupby(['Year'])
    year_totals = year_groupby.size()

    return year_totals

# Create a DataFrame with the yearly overview of all the unique items in a particular column
def createYearlyOverview(df,columnName):
    
    #list of all unique items in the column
    columnList = df[columnName].unique()
    
    #Ouput frame
    yearlyOverviewFrame = pd.DataFrame()
    
    # For each item create the yearly overview and add these to the Overview frame
    for item in columnList:
        pandasSeries = createYearOverviewItem(df,columnName,item)
        yearlyOverviewFrame[item] = pandasSeries
    
    return yearlyOverviewFrame

# Make an overview of percentages
def createYearlyOverviewPercentages(dfYearOverviewIn):

    dfYearOverview = dfYearOverviewIn.copy()
    
    # Adding a total to the year overview DataFrame
    dfYearOverview['Total'] = dfYearOverview.sum(axis=1)
    
    # Normalizing
    for colm in dfYearOverview.columns.values:
        dfYearOverview[colm] = dfYearOverview[colm]/dfYearOverview['Total']

    dfYearOverview = dfYearOverview.drop(['Total'],axis=1)
    
    return dfYearOverview

# %%
# Plot functions
def createPieChart(percent_series,title):
    
    percent_series.name = ''
    #lenIndex = len(percent_series.index)
    #tup1 = (0.1,)
    #tup2 = (0.0,)*(lenIndex-1)
    #explode = tup1 + tup2
    
    #percent_series.plot.pie(subplots=True,figsize=(5, 5),autopct='%1.1f%%',shadow=True,\
    #                     startangle=90,explode=explode,fontsize=12,title=title)
    percent_series.plot.pie(subplots=True,figsize=(5, 5),autopct='%1.1f%%',shadow=True,\
                         startangle=90,fontsize=12,title=title)

# %%
# Loading the raw shark data set
shark_df_raw = pd.read_excel('data/GSAF5.xls')

# %%
# Filtering and cleaning of the data
shark_df_nanfilt = shark_df_raw.notnull()

# Date filter and selecting the years 1950 - 2016
shark_df_datefilt = shark_df_raw[shark_df_nanfilt['Date'] == True]
print "\nLength data set after date filtering: {}".format(len(shark_df_datefilt))
shark_df_yearfilt = shark_df_datefilt[(shark_df_datefilt['Year'] > 1949) & (shark_df_datefilt['Year'] < 2017)]
print "\nLength data set after 1950-2016 selection: {}".format(len(shark_df_yearfilt))

# Removing the NaN fields from 'Type' column
shark_df_typefilt = shark_df_yearfilt.notnull()
shark_df_types = shark_df_yearfilt[shark_df_typefilt['Type'] == True]
print "\nLength data set after NaN filtering of the 'Type' column: {}".format(len(shark_df_types))

# Taking a look at the attacks which are questionable (Invalid)
invalid_type_df = shark_df_types[shark_df_types['Type'] == 'Invalid']
print "\nTotal 'Invalid' (questionable) types of atacks: {}".format(len(invalid_type_df))

# Removing the Invalid attacks and use the new DataFrame for analysis
shark_df = shark_df_types[shark_df_types['Type'] != 'Invalid']
print "\nTotal entries we're going to work with: {}".format(len(shark_df))
# Out:
# Length data set after date filtering: 6035
#
# Length data set after 1950-2016 selection: 4301
#
# Length data set after NaN filtering of the 'Type' column: 4300
#
# Total 'Invalid' (questionable) types of atacks: 357
#
# Total entries we're going to work with: 3943

# %% [markdown]
# # Checking the species and getting the total

# %%
# Adding a column where the species are cleaned and grouped together
# First replacing NaNs in 'Species ' column
shark_df.loc[:,'Species '] = shark_df.loc[:,'Species '].fillna('Unspecified')
shark_df.loc[:,'Species filtered'] = shark_df.loc[:,'Species '].apply(filterSpecies)

# Copy the 'Year' and 'Species filtered' columns to a new data frame
yearlySpecies_df = shark_df[['Year','Species filtered']].copy()

# Create a pandas series with the yearly overview of all species
yearlyOveviewSpecies = createYearlyOverview(yearlySpecies_df,'Species filtered')
total = pd.DataFrame()
total['Total'] = yearlyOveviewSpecies.sum(axis=1)
total.plot()
# Out:
# /home/koen/anaconda3/envs/bunnies/lib/python2.7/site-packages/pandas/core/indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/koen/anaconda3/envs/bunnies/lib/python2.7/site-packages/pandas/core/indexing.py:297: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)

# %%
# Creating the confidence limits, assuming a poisson distribution for each measurement
total['err'] = total['Total'].apply(lambda x: np.sqrt(x))
total['ptwosig'] = total['Total']+2*total['err']
total['mtwosig'] = total['Total']-2*total['err']

# Plotting the total shark attacks per year with a nice style and confidence belts
plt.figure()
total['Total'].plot(linewidth=3,color='blue',title='Total World Wide Shark Attacks',fontsize=12)
#plt.plot(total.index,total.Total,linewidth=3)
plt.fill_between(total.index, total['mtwosig'], total['ptwosig'], color='b', alpha=0.2)
blueleg  = mpatches.Patch(color='blue', label='Total shark attacks 1950-2016')
confbelt = mpatches.Patch(color='blue', alpha=0.2, label='2-sigma confidence belt')
plt.legend(handles=[blueleg,confbelt],loc=2)

plt.show()

# %% [markdown]
# # Checking the types

# %%
# Creating a yearly overview dataframe with the type of attacks
yearlyOverviewTypes = createYearlyOverview(shark_df,'Type')

# Filling NaN with zeros
for colm in yearlyOverviewTypes.columns.values:
    yearlyOverviewTypes.loc[:,colm] = yearlyOverviewTypes.loc[:,colm].fillna(0.0)

# Removing the redundant column 'Boating'
yearlyOverviewTypes['Boat'] = yearlyOverviewTypes['Boat']+yearlyOverviewTypes['Boating']
yearlyOverviewTypes = yearlyOverviewTypes.drop(['Boating'],axis=1)

percentagesTypes = createYearlyOverviewPercentages(yearlyOverviewTypes)

# Plotting the percentages for each type per year
plt.figure()
percentagesTypes.plot.area()

# %% [markdown]
# # Checking the Activity

# %%
# Replacing NaN in the 'Activity' columns by empty strings
shark_df.loc[:,'Activity'] = shark_df.loc[:,'Activity'].fillna('')
shark_df.loc[:,'Activity grouped'] = shark_df.loc[:,'Activity'].apply(groupActivity)

# Creating a yearly overview dataframe with the type of attacks
yearlyOverviewActiv = createYearlyOverview(shark_df,'Activity grouped')

# Filling NaN with zeros
for colm in yearlyOverviewActiv.columns.values:
    yearlyOverviewActiv.loc[:,colm] = yearlyOverviewActiv.loc[:,colm].fillna(0.0)
    
# Removing the redundant column 'boarding' and 'standing'
yearlyOverviewActiv['surfing'] = yearlyOverviewActiv['surfing']+yearlyOverviewActiv['boarding']
yearlyOverviewActiv = yearlyOverviewActiv.drop(['boarding'],axis=1)
yearlyOverviewActiv['wading'] = yearlyOverviewActiv['wading']+yearlyOverviewActiv['standing']
yearlyOverviewActiv = yearlyOverviewActiv.drop(['standing'],axis=1)

percentagesActiv = createYearlyOverviewPercentages(yearlyOverviewActiv)

# Plotting the percentages for each type per year
plt.figure()
percentagesActiv.plot.area()

# %%
# Doing a check
Activ8016 = percentagesActiv[percentagesActiv.index > 1980]
AllActivAverage = Activ8016.mean()
print AllActivAverage
# Out:
# surfing       0.385388
# snorkeling    0.028283
# skiing        0.010466
# diving        0.084241
# fishing       0.150875
# floating      0.004252
# other         0.109451
# wading        0.052679
# swimming      0.135449
# kayaking      0.008989
# walking       0.004148
# playing       0.006169
# sitting       0.005024
# rowing        0.004005
# canoeing      0.002002
# watching      0.001257
# bathing       0.002293
# paddling      0.003494
# treading      0.001534
# dangling      0.000000
# dtype: float64

# %%
def checkTopActivities(inputString):
    
    activity = inputString
    if activity not in ['surfing','swimming','fishing','diving','wading','boarding','standing']:
        activity = 'other'
        
    return activity

# %%
# Grouping the main activities
shark_df.loc[:,'Activity top'] = shark_df.loc[:,'Activity grouped'].apply(checkTopActivities)

# Creating a yearly overview dataframe with the type of attacks
yearlyOverviewActivTop = createYearlyOverview(shark_df,'Activity top')

# Filling NaN with zeros
for colm in yearlyOverviewActivTop.columns.values:
    yearlyOverviewActivTop.loc[:,colm] = yearlyOverviewActivTop.loc[:,colm].fillna(0.0)
    
# Removing the redundant column 'boarding' and 'standing'
yearlyOverviewActivTop['surfing'] = yearlyOverviewActivTop['surfing']+yearlyOverviewActivTop['boarding']
yearlyOverviewActivTop = yearlyOverviewActivTop.drop(['boarding'],axis=1)
yearlyOverviewActivTop['wading'] = yearlyOverviewActivTop['wading']+yearlyOverviewActivTop['standing']
yearlyOverviewActivTop = yearlyOverviewActivTop.drop(['standing'],axis=1)

percentagesActivTop = createYearlyOverviewPercentages(yearlyOverviewActivTop)

# Plotting the percentages for each type per year
plt.figure()
percentagesActivTop.plot.area()

# %%
# Creating a pie chart for 1980-2016
ActivTop8016 = percentagesActivTop[percentagesActivTop.index > 1980]
ActivTopAverage = ActivTop8016.mean()
print ActivTopAverage
createPieChart(ActivTopAverage,'Activity during attack (1980-2016)')
# Out:
# surfing     0.385388
# other       0.191368
# diving      0.084241
# fishing     0.150875
# wading      0.052679
# swimming    0.135449
# dtype: float64

# %% [markdown]
# # Checking the Countries

# %%
shark_df['Country'].value_counts()[:10]
# Out:
# USA                 1646
# AUSTRALIA            691
# SOUTH AFRICA         409
# PAPUA NEW GUINEA     109
# BRAZIL                88
# BAHAMAS               78
# NEW ZEALAND           72
# REUNION               53
# MEXICO                52
# NEW CALEDONIA         45
# Name: Country, dtype: int64

# %%
def selectTopCountries(inputString):
    
    # These turned out to be the top-4 countries in the period of 1980-2016
    country = inputString
    if country not in ['USA','AUSTRALIA','SOUTH AFRICA','BRAZIL']:
        country = 'OTHER'
        
    return country

# %%
# Replacing NaN in the 'Activity' columns by empty strings
shark_df.loc[:,'Country'] = shark_df.loc[:,'Country'].fillna('')
shark_df.loc[:,'Country top'] = shark_df.loc[:,'Country'].apply(selectTopCountries)

# Creating a yearly overview dataframe with the type of attacks
yearlyOverviewCountry = createYearlyOverview(shark_df,'Country top')

# Filling NaN with zeros
for colm in yearlyOverviewCountry.columns.values:
    yearlyOverviewCountry.loc[:,colm] = yearlyOverviewCountry.loc[:,colm].fillna(0.0)

percentagesCountry = createYearlyOverviewPercentages(yearlyOverviewCountry)

# Plotting the percentages for each type per year
plt.figure()
percentagesCountry.plot.area()

# %%
# Creating a pie chart for 1980-2016
Country8016 = percentagesCountry[percentagesCountry.index > 1980]
CountryAverage = Country8016.mean()

print CountryAverage
#CountryAverage.plot.pie(subplots=True,figsize=(5, 5))
createPieChart(CountryAverage,'Countries with most attacks (1980-2016)')
# Out:
# USA             0.500305
# AUSTRALIA       0.148215
# SOUTH AFRICA    0.111894
# OTHER           0.205445
# BRAZIL          0.034142
# dtype: float64

# %% [markdown]
# ## Checks

# %%
shark_df
# Out:
#        Case Number                  Date    Year          Type        Country  \
# 13      2016.12.27           27-Dec-2016  2016.0    Unprovoked            USA
# 14      2016.12.24           24-Dec-2016  2016.0    Unprovoked      AUSTRALIA
# 15      2016.12.19           19-Dec-2016  2016.0    Unprovoked   SOUTH AFRICA
# 16      2016.12.14           14-Dec-2016  2016.0    Unprovoked      AUSTRALIA
# 18      2016.12.10           10-Dec-2016  2016.0    Unprovoked        England
# 19      2016.12.06           06-Dec-2016  2016.0      Provoked      AUSTRALIA
# 20      2016.12.01           01-Dec-2016  2016.0    Unprovoked      AUSTRALIA
# 21      2016.11.28           28-Nov-2016  2016.0      Provoked      AUSTRALIA
# 22      2016.11.14           14-Nov-2016  2016.0    Unprovoked            USA
# 23      2016.10.30           30-Oct-2016  2016.0    Unprovoked            USA
# 24      2016.10.29           29-Oct-2016  2016.0    Unprovoked            USA
# 25      2016.10.24           24-Oct-2016  2016.0    Unprovoked      AUSTRALIA
# 26      2016.10.21           21-Oct-2016  2016.0    Unprovoked            USA
# 27      2016.10.15           15-Oct-2016  2016.0    Unprovoked      AUSTRALIA
# 28      2016.10.14           14-Oct-2016  2016.0    Unprovoked            USA
# 30      2016.10.12           12-Oct-2016  2016.0    Unprovoked      AUSTRALIA
# 31      2016.10.10           10-Oct-2016  2016.0    Unprovoked            USA
# 32      2016.10.02           02-Oct-2016  2016.0    Unprovoked            USA
# 33      2016.10.01           01-Oct-2016  2016.0    Unprovoked            USA
# 34      2016.09.26           26-Sep-2016  2016.0    Unprovoked      AUSTRALIA
# 35    2016.09.18.c           18-Sep-2016  2016.0    Unprovoked            USA
# 36    2016.09.18.b           18-Sep-2016  2016.0    Unprovoked            USA
# 37    2016.09.18.a           18-Sep-2016  2016.0    Unprovoked            USA
# 38    2016.09.17.b           17-Sep-2016  2016.0    Unprovoked            USA
# 39    2016.09.17.a           17-Sep-2016  2016.0    Unprovoked      AUSTRALIA
# 40      2016.09.15           16-Sep-2016  2016.0    Unprovoked      AUSTRALIA
# 41    2016.09.15.R           15-Sep-2016  2016.0          Boat      AUSTRALIA
# 42      2016.09.11           11-Sep-2016  2016.0    Unprovoked            USA
# 43      2016.09.07           07-Sep-2016  2016.0    Unprovoked            USA
# 44      2016.09.06           06-Sep-2016  2016.0    Unprovoked  NEW CALEDONIA
# ...            ...                   ...     ...           ...            ...
# 4280    1950.08.00              Aug-1950  1950.0    Unprovoked   SAUDI ARABIA
# 4281  1950.07.27.R  Reported 27-Jul-1950  1950.0       Boating      AUSTRALIA
# 4282    1950.07.21           21-Jul-1950  1950.0    Unprovoked          JAPAN
# 4283    1950.07.19            1950.07.19  1950.0      Provoked          ITALY
# 4284    1950.07.14           15-Jul-1950  1950.0    Unprovoked           CUBA
# 4285    1950.07.10           10-Jul-1950  1950.0    Unprovoked            USA
# 4287    1950.07.00              Jul-1950  1950.0    Unprovoked            USA
# 4288    1950.06.25           25-Jun-1950  1950.0    Unprovoked            USA
# 4289    1950.06.06           06-Jun-1950  1950.0  Sea Disaster            USA
# 4290    1950.05.24           24-May-1950  1950.0    Unprovoked   SOUTH AFRICA
# 4291    1950.05.01           01-May-1950  1950.0       Boating          ITALY
# 4292  1950.04.09.b           09-Apr-1950  1950.0  Sea Disaster      AUSTRALIA
# 4293  1950.04.09.a           09-Apr-1950  1950.0    Unprovoked   SOUTH AFRICA
# 4294    1950.03.26           26-Mar-1950  1950.0    Unprovoked   SOUTH AFRICA
# 4295    1950.03.08           08-Mar-1950  1950.0    Unprovoked   SOUTH AFRICA
# 4297  1950.02.18.R  Reported 18-Feb-1950  1950.0    Unprovoked      AUSTRALIA
# 4298    1950.02.11           11-Feb-1950  1950.0    Unprovoked   SOUTH AFRICA
# 4300  1950.01.12.R  Reported 12-Jan-1950  1950.0    Unprovoked      AUSTRALIA
# 4301  1950.00.00.m                  1950  1950.0       Boating      AUSTRALIA
# 4302  1950.00.00.l                  1950  1950.0    Unprovoked      SRI LANKA
# 4303  1950.00.00.k                  1950  1950.0    Unprovoked      SRI LANKA
# 4304  1950.00.00.j           1950 - 1951  1950.0    Unprovoked        LIBERIA
# 4305  1950.00.00.i           Summer 1950  1950.0    Unprovoked      INDONESIA
# 4306  1950.00.00.h                  1950  1950.0    Unprovoked            USA
# 4308  1950.00.00.f                  1950  1950.0    Unprovoked         PANAMA
# 4309  1950.00.00.e           Summer 1950  1950.0    Unprovoked         GREECE
# 4310  1950.00.00.d                  1950  1950.0    Unprovoked      SINGAPORE
# 4311  1950.00.00.c                  1950  1950.0    Unprovoked  NEW CALEDONIA
# 4312  1950.00.00.b              Ca. 1950  1950.0    Unprovoked  NEW CALEDONIA
# 4313  1950.00.00.a              Ca. 1950  1950.0    Unprovoked           FIJI
#
#                        Area  \
# 13                  Florida
# 14        Western Australia
# 15    Western Cape Province
# 16        Western Australia
# 18                  Suffolk
# 19          New South Wales
# 20          New South Wales
# 21                 Victoria
# 22                   Hawaii
# 23                  Florida
# 24                  Florida
# 25          New South Wales
# 26                   Hawaii
# 27               Queensland
# 28                   Hawaii
# 30          New South Wales
# 31                   Oregon
# 32                  Florida
# 33                  Florida
# 34          New South Wales
# 35                  Florida
# 36                  Florida
# 37                  Florida
# 38               California
# 39                 Victoria
# 40                 Victoria
# 41        Western Australia
# 42                  Florida
# 43                   Hawaii
# 44           North Province
# ...                     ...
# 4280       Eastern Province
# 4281        South Australia
# 4282        Sago Prefecture
# 4283                 Savona
# 4284          Caribbean Sea
# 4285                  Texas
# 4287                Florida
# 4288               New York
# 4289                Florida
# 4290          KwaZulu-Natal
# 4291         Tyrrhenian Sea
# 4292             Queensland
# 4293  Eastern Cape Province
# 4294  Eastern Cape Province
# 4295          KwaZulu-Natal
# 4297      Western Australia
# 4298          KwaZulu-Natal
# 4300               Victoria
# 4301               Tasmania
# 4302       Eastern Province
# 4303      Southern Province
# 4304            Montserrado
# 4305        Jakarta Harbour
# 4306                Florida
# 4308             Canal Zone
# 4309                    NaN
# 4310       Singapore Harbor
# 4311         North Province
# 4312         North Province
# 4313                    NaN
#
#                                                Location  \
# 13    Avalon State Park Beach, North Hutchinson Isla...
# 14                     Bundegi Sanctuary Zone, Ningaloo
# 15                    Keurbooms Lagoon, Plettenberg Bay
# 16                                          Trigg Beach
# 18                                           Felixstowe
# 19                                            Merimbula
# 20                            Booti Booti National Park
# 21                                          Queenscliff
# 22                           Kamaole Beach Park I, Maui
# 23            Mayport Naval Station Beach, Duval County
# 24                  Mayport Naval Station  Duval County
# 25                                    Broken Head Beach
# 26                              Hooipa Beach Park, Maui
# 27                               Kings Beach, Caloundra
# 28                     Charlie Young Beach, Kihei, Maui
# 30                               Sharpes Beach, Ballina
# 31       Indian Beach, Ecola State Park, Clatsop County
# 32                     New Smyrna Beach, Volusia County
# 33                     New Smyrna Beach, Volusia County
# 34                            Lighthouse Beach, Ballina
# 35                     New Smyrna Beach, Volusia County
# 36                     New Smyrna Beach, Volusia County
# 37                     New Smyrna Beach, Volusia County
# 38       Bunkers, Humboldt Bay, Eureka, Humboldt County
# 39                                     Thirteenth Beach
# 40                                          Bells Beach
# 41                                              Bunbury
# 42                        Ponte Vedra, St. Johns County
# 43                                         Makaha, Oahu
# 44                                               Koumac
# ...                                                 ...
# 4280                East of the Ras Tanura-Jubail area
# 4281                                        Streaky Bay
# 4282                                       Ariakeno Bay
# 4283                                            Albenga
# 4284                                                NaN
# 4285                                   Near Port Arthur
# 4287              Rock Harbor, Key Largo, Monroe County
# 4288                      Beach 103rd Street, Rockaway
# 4289                       275 miles northeast of Miami
# 4290                                        Port Edward
# 4291                              Sprizze, Isola d'Elba
# 4292                                     Cooper's Point
# 4293                      Off Port Elizabeth breakwater
# 4294              Off bank of Ntshala River, Morgan Bay
# 4295                                North Beach, Durban
# 4297                                   Cottesloe, Perth
# 4298                                South Beach, Durban
# 4300                               South Werribee Beach
# 4301                                          Triabunna
# 4302                                   Heda Oya Estuary
# 4303                                           Dodnduwa
# 4304                                           Monrovia
# 4305                            On rock near Yacht Club
# 4306                   Jacksonville Beach, Duval County
# 4308       300 yards west of mouth of the Chagres River
# 4309                                    Piraeus, Athens
# 4310                                                NaN
# 4311                                Voh, near meatworks
# 4312                         Mangalia Reef above Touho
# 4313                                       Near Lautoka
#
#                                                Activity  \
# 13                                              Surfing
# 14                                           Snorkeling
# 15                                         Surf skiing
# 16                                          Free diving
# 18                                          Windsurfing
# 19                                         Surf fishing
# 20                                              Surfing
# 21                                              Fishing
# 22                                             Floating
# 23                                              Surfing
# 24                                              Surfing
# 25                                              Surfing
# 26                                              Surfing
# 27                                              Surfing
# 28                                           Snorkeling
# 30                                              Surfing
# 31                                              Surfing
# 32                                              Surfing
# 33                                               Surfng
# 34                                              Surfing
# 35                                              Surfing
# 36                                              Surfing
# 37                                              Surfing
# 38                                              Surfing
# 39                                              Surfing
# 40                                              Surfing
# 41                                              Fishing
# 42                                               Wading
# 43                                             Swimming
# 44                                         Kite surfing
# ...                                                 ...
# 4280                                             Diving
# 4281                                            Fishing
# 4282                                           Swimming
# 4283                                            Fishing
# 4284  Swept off deck of S.S.Frontenac enroute from W...
# 4285                                           Swimming
# 4287  Goggle-diving for seaweeds, but standing in water
# 4288                                          Swimming
# 4289  Survived crash of two-engine  C-46 transport p...
# 4290                                     Treading water
# 4291                                  Fishing on a boat
# 4292  Sea Disaster, sinking of the fishing  launch M...
# 4293  Fishing, sitting in stern of small boat, feet ...
# 4294                                             Wading
# 4295                                   Lifesaving drill
# 4297                                       Spearfishing
# 4298                                       Body surfing
# 4300                                           Swimming
# 4301            Sitting on side of dinghy mending a net
# 4302                                      Shark fishing
# 4303                                       Spearfishing
# 4304              Defecating in water beneath the docks
# 4305                                       Bending over
# 4306                                           Standing
# 4308                                           Bathing
# 4309                                           Swimming
# 4310                                   Diving for coins
# 4311  Spearfishing, but walking carrying fish on end...
# 4312            Helmet diving, collecting trochus shell
# 4313
#
#                                     Name Sex       ...       \
# 13                            Zack Davis    M      ...
# 14                                female    F      ...
# 15                             Ben Swart    M      ...
# 16                           Tim Roberts    M      ...
# 18                     Christopher Mills    M      ...
# 19                        Jesse Phillips    M      ...
# 20                         Colin Rowland    M      ...
# 21                         Rod McFarlane    M      ...
# 22                       Barbara Zawacki    F      ...
# 23                          Daniel Adams    M      ...
# 24                         Derrick Shoup    M      ...
# 25                      Jade Fitzpatrick    M      ...
# 26                        Federico Jaime    M      ...
# 27                         Cooper Hallam    M      ...
# 28                                female    F      ...
# 30                            Seneca Rus    M      ...
# 31                         Joseph Tanner    M      ...
# 32                                  male    M      ...
# 33                                  male    M      ...
# 34                          Cooper Allen    M      ...
# 35                                  male    M      ...
# 36                        Chucky Luciano    M      ...
# 37                                  male    M      ...
# 38                                  Yuma    M      ...
# 39                       Rory Angiolella    M      ...
# 40                                  male    M      ...
# 41                Occupant: Ben Stratton  NaN      ...
# 42                                  male    M      ...
# 43                           Lulu Bagnol    F      ...
# 44                          David Jewell    M      ...
# ...                                  ...  ...      ...
# 4280                       a pearl diver    M      ...
# 4281                  40' fishing cutter  NaN      ...
# 4282                                male    M      ...
# 4283                                male  NaN      ...
# 4284  Johan Loekstad, a Norwegian seaman    M      ...
# 4285                     Mark Majors III    M      ...
# 4287                      Warren Rathgen    M      ...
# 4288                      Joseph Salengo    M      ...
# 4289                        Pedro Guzman    M      ...
# 4290             Dr. Leonard Read Tibbet    M      ...
# 4291                        Remo Adriani    M      ...
# 4292                       John McDonald    M      ...
# 4293                                male    M      ...
# 4294                       Mr. N. Wright    M      ...
# 4295                      Brian Von Berg    M      ...
# 4297                                male    M      ...
# 4298                       Clive Dumayne    M      ...
# 4300                           D. Martin    M      ...
# 4301                          Neil Drake    M      ...
# 4302                           Aboobaker    M      ...
# 4303                    Langston Pereira    M      ...
# 4304                       a dock worker    M      ...
# 4305                               child    M      ...
# 4306                       George Carter    M      ...
# 4308                  male, a US soldier    M      ...
# 4309                                 NaN  NaN      ...
# 4310             Abdullah, a Malay diver    M      ...
# 4311                                male    M      ...
# 4312                                male    M      ...
# 4313                              Fijian    M      ...
#
#                                                    href Case Number.1  \
# 13    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.12.27
# 14    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.12.24
# 15    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.12.19
# 16    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.12.14
# 18    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.12.10
# 19    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.12.06
# 20    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.12.01
# 21    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.11.28
# 22    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.11.14
# 23    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.10.30
# 24    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.10.29
# 25    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.10.24
# 26    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.10.21
# 27    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.10.15
# 28    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.10.14
# 30    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.10.12
# 31    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.10.10
# 32    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.10.02
# 33    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.10.01
# 34    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.26
# 35    http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
# 36    http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.b
# 37    http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.a
# 38    http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.17.b
# 39    http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.17.a
# 40    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
# 41    http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.15.R
# 42    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.11
# 43    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.07
# 44    http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.06
# ...                                                 ...           ...
# 4280  http://sharkattackfile.net/spreadsheets/pdf_di...    1950.08.00
# 4281  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.07.27.R
# 4282  http://sharkattackfile.net/spreadsheets/pdf_di...    1950.07.21
# 4283  http://sharkattackfile.net/spreadsheets/pdf_di...    1950.07.19
# 4284  http://sharkattackfile.net/spreadsheets/pdf_di...    1950.07.14
# 4285  http://sharkattackfile.net/spreadsheets/pdf_di...    1950.07.10
# 4287  http://sharkattackfile.net/spreadsheets/pdf_di...    1950.07.00
# 4288  http://sharkattackfile.net/spreadsheets/pdf_di...    1950.06.25
# 4289  http://sharkattackfile.net/spreadsheets/pdf_di...    1950.06.06
# 4290  http://sharkattackfile.net/spreadsheets/pdf_di...    1950.05.24
# 4291  http://sharkattackfile.net/spreadsheets/pdf_di...    1950.05.01
# 4292  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.04.09.b
# 4293  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.04.09.a
# 4294  http://sharkattackfile.net/spreadsheets/pdf_di...    1950.03.26
# 4295  http://sharkattackfile.net/spreadsheets/pdf_di...    1950.03.08
# 4297  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.02.18.R
# 4298  http://sharkattackfile.net/spreadsheets/pdf_di...    1950.02.11
# 4300  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.01.12.R
# 4301  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.00.00.m
# 4302  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.00.00.l
# 4303  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.00.00.k
# 4304  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.00.00.j
# 4305  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.00.00.i
# 4306  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.00.00.h
# 4308  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.00.00.f
# 4309  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.00.00.e
# 4310  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.00.00.d
# 4311  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.00.00.c
# 4312  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.00.00.b
# 4313  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.00.00.a
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23  Species filtered  \
# 13      2016.12.27         6023.0         NaN         NaN       Unspecified
# 14      2016.12.24         6022.0         NaN         NaN       Unspecified
# 15      2016.12.19         6021.0         NaN         NaN       white shark
# 16      2016.12.14         6020.0         NaN         NaN       Unspecified
# 18      2016.12.10         6018.0         NaN         NaN       Unspecified
# 19      2016.12.06         6017.0         NaN         NaN   wobbegong shark
# 20      2016.12.01         6016.0         NaN         NaN       white shark
# 21      2016.11.28         6015.0         NaN         NaN   sevengill shark
# 22      2016.11.14         6014.0         NaN         NaN       tiger shark
# 23      2016.10.30         6013.0         NaN         NaN       Unspecified
# 24      2016.10.29         6012.0         NaN         NaN       Unspecified
# 25      2016.10.24         6011.0         NaN         NaN       Unspecified
# 26      2016.10.21         6010.0         NaN         NaN       Unspecified
# 27      2016.10.15         6009.0         NaN         NaN       Unspecified
# 28      2016.10.14         6008.0         NaN         NaN       Unspecified
# 30      2016.10.12         6006.0         NaN         NaN       Unspecified
# 31      2016.10.10         6005.0         NaN         NaN       Unspecified
# 32      2016.10.02         6004.0         NaN         NaN       Unspecified
# 33      2016.10.01         6003.0         NaN         NaN       Unspecified
# 34      2016.09.26         6002.0         NaN         NaN       white shark
# 35    2016.09.18.c         6001.0         NaN         NaN       Unspecified
# 36    2016.09.18.b         6000.0         NaN         NaN       Unspecified
# 37    2016.09.18.a         5999.0         NaN         NaN       Unspecified
# 38    2016.09.17.b         5998.0         NaN         NaN       Unspecified
# 39    2016.09.17.a         5997.0         NaN         NaN       Unspecified
# 40      2016.09.15         5996.0         NaN         NaN       Unspecified
# 41    2016.09.15.R         5995.0         NaN         NaN       Unspecified
# 42      2016.09.11         5994.0         NaN         NaN       Unspecified
# 43      2016.09.07         5993.0         NaN         NaN       tiger shark
# 44      2016.09.06         5992.0         NaN         NaN       Unspecified
# ...            ...            ...         ...         ...               ...
# 4280    1950.08.00         1756.0         NaN         NaN       Unspecified
# 4281  1950.07.27.R         1755.0         NaN         NaN       white shark
# 4282    1950.07.21         1754.0         NaN         NaN       Unspecified
# 4283    1950.07.19         1753.0         NaN         NaN       Unspecified
# 4284    1950.07.14         1752.0         NaN         NaN       Unspecified
# 4285    1950.07.10         1751.0         NaN         NaN  hammerhead shark
# 4287    1950.07.00         1749.0         NaN         NaN       Unspecified
# 4288    1950.06.25         1748.0         NaN         NaN       Unspecified
# 4289    1950.06.06         1747.0         NaN         NaN       Unspecified
# 4290    1950.05.24         1746.0         NaN         NaN       Unspecified
# 4291    1950.05.01         1745.0         NaN         NaN       white shark
# 4292  1950.04.09.b         1744.0         NaN         NaN       Unspecified
# 4293  1950.04.09.a         1743.0         NaN         NaN       Unspecified
# 4294    1950.03.26         1742.0         NaN         NaN       Unspecified
# 4295    1950.03.08         1741.0         NaN         NaN       Unspecified
# 4297  1950.02.18.R         1739.0         NaN         NaN       Unspecified
# 4298    1950.02.11         1738.0         NaN         NaN       white shark
# 4300  1950.01.12.R         1736.0         NaN         NaN       Unspecified
# 4301  1950.00.00.m         1735.0         NaN         NaN       white shark
# 4302  1950.00.00.l         1734.0         NaN         NaN       lemon shark
# 4303  1950.00.00.k         1733.0         NaN         NaN        reef shark
# 4304  1950.00.00.j         1732.0         NaN         NaN       Unspecified
# 4305  1950.00.00.i         1731.0         NaN         NaN       tiger shark
# 4306  1950.00.00.h         1730.0         NaN         NaN       Unspecified
# 4308  1950.00.00.f         1728.0         NaN         NaN       Unspecified
# 4309  1950.00.00.e         1727.0         NaN         NaN       Unspecified
# 4310  1950.00.00.d         1726.0         NaN         NaN       Unspecified
# 4311  1950.00.00.c         1725.0         NaN         NaN       Unspecified
# 4312  1950.00.00.b         1724.0         NaN         NaN       Unspecified
# 4313  1950.00.00.a         1723.0         NaN         NaN       Unspecified
#
#      Activity grouped Activity top   Country top
# 13            surfing      surfing           USA
# 14         snorkeling        other     AUSTRALIA
# 15             skiing        other  SOUTH AFRICA
# 16             diving       diving     AUSTRALIA
# 18            surfing      surfing         OTHER
# 19            fishing      fishing     AUSTRALIA
# 20            surfing      surfing     AUSTRALIA
# 21            fishing      fishing     AUSTRALIA
# 22           floating        other           USA
# 23            surfing      surfing           USA
# 24            surfing      surfing           USA
# 25            surfing      surfing     AUSTRALIA
# 26            surfing      surfing           USA
# 27            surfing      surfing     AUSTRALIA
# 28         snorkeling        other           USA
# 30            surfing      surfing     AUSTRALIA
# 31            surfing      surfing           USA
# 32            surfing      surfing           USA
# 33              other        other           USA
# 34            surfing      surfing     AUSTRALIA
# 35            surfing      surfing           USA
# 36            surfing      surfing           USA
# 37            surfing      surfing           USA
# 38            surfing      surfing           USA
# 39            surfing      surfing     AUSTRALIA
# 40            surfing      surfing     AUSTRALIA
# 41            fishing      fishing     AUSTRALIA
# 42             wading       wading           USA
# 43           swimming     swimming           USA
# 44            surfing      surfing         OTHER
# ...               ...          ...           ...
# 4280           diving       diving         OTHER
# 4281          fishing      fishing     AUSTRALIA
# 4282         swimming     swimming         OTHER
# 4283          fishing      fishing         OTHER
# 4284            other        other         OTHER
# 4285         swimming     swimming           USA
# 4287           diving       diving           USA
# 4288         swimming     swimming           USA
# 4289            other        other           USA
# 4290         treading        other  SOUTH AFRICA
# 4291          fishing      fishing         OTHER
# 4292          fishing      fishing     AUSTRALIA
# 4293          fishing      fishing  SOUTH AFRICA
# 4294           wading       wading  SOUTH AFRICA
# 4295            other        other  SOUTH AFRICA
# 4297          fishing      fishing     AUSTRALIA
# 4298          surfing      surfing  SOUTH AFRICA
# 4300         swimming     swimming     AUSTRALIA
# 4301          sitting        other     AUSTRALIA
# 4302          fishing      fishing         OTHER
# 4303          fishing      fishing         OTHER
# 4304            other        other         OTHER
# 4305            other        other         OTHER
# 4306         standing     standing           USA
# 4308          bathing        other         OTHER
# 4309         swimming     swimming         OTHER
# 4310           diving       diving         OTHER
# 4311          fishing      fishing         OTHER
# 4312           diving       diving         OTHER
# 4313            other        other         OTHER
#
# [3943 rows x 28 columns]

# %%
def Check(column,item):
    ItemYearly_df = shark_df[['Year',column]].copy()
    yearlyOveviewItem = createYearOverviewItem(ItemYearly_df,column,item)
    yearlyOveviewItem.plot()
    
def Check2(column,stop):
    ItemYearly_df = shark_df[['Year',column]].copy()
    items = ItemYearly_df[column].unique()
    for i, item in enumerate(items):
        print item
        yearlyOveviewItem = createYearOverviewItem(ItemYearly_df,column,item)
        yearlyOveviewItem.plot()
        if (i == stop):
            break

# %%
#Check2('Activity',10)
