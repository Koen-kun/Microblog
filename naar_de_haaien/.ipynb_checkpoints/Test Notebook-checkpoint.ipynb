# %%
import pandas as pd

# %%
pd.read_excel('data/GSAF5.xls')
# Out:
#         Case Number                  Date    Year        Type       Country  \
# 0        2017.01.21           21-Jan-2017  2017.0  Unprovoked     AUSTRALIA
# 1      2017.01.13.b           13-Jan-2017  2017.0  Unprovoked     AUSTRALIA
# 2      2017.01.13.a           13-Jan-2017  2017.0  Unprovoked           USA
# 3        2017.01.09           09-Jan-2017  2017.0  Unprovoked     INDONESIA
# 4      2017.01.08.R  Reported 08-Jan-2017     NaN         NaN     AUSTRALIA
# 5        2017.01.05           05-Jan-2017  2017.0  Unprovoked           USA
# 6        2017.01.03           03-Jan-2017  2017.0     Invalid     AUSTRALIA
# 7        2016.12.27           27-Dec-2016  2016.0  Unprovoked           USA
# 8        2016.12.24           24-Dec-2016  2016.0  Unprovoked     AUSTRALIA
# 9        2016.12.19           19-Dec-2016  2016.0  Unprovoked  SOUTH AFRICA
# 10       2016.12.14           14-Dec-2016  2016.0  Unprovoked     AUSTRALIA
# ...

# %%
shark_df = pd.read_excel('data/GSAF5.xls')

# %%
print len(shark_df)
# Out:
# 25588
